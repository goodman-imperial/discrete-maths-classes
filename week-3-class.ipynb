# %% [markdown]
# # Week 3 - class
#
# We'll go through the 2014 Algorithms and Complexity exam, Q2 (pasted below). For part (b), rather than writing pseudocode I'd like you to write code that implements it. I've included templates in Python and C++ below. I'd suggest you have a go at least at the coding part before the class.
#
# ![image.png](attachment:image.png)
#
# Here's the template in Python:

# %%
def majority(x):
    # should return an index i of the majority element
    # if there is one, so that x[i] is the majority element
    # or -1 if there is no majority element
    return -1 # replace this with your solution

x1 = [1,2,3,4,3,2,2,2,2,2,2]
x2 = [8,9,10]
maj1 = majority(x1)
maj2 = majority(x2)
print(maj1, maj2, x1[maj1])
if maj1==-1:
    print("Wrong! (1)")
elif maj1>=len(x1):
    print("Wrong! (2)")
elif x1[maj1]!=2:
    print("Wrong! (3)")
elif maj2!=-1:
    print("Wrong! (4)")
else:
    print("You got it!")
# Out:
# -1 -1 2
# Wrong! (1)

# %% [markdown]
# ## C++ template
#
# ```C++
# #include<iostream>
# #include<vector>
# #include<algorithm>
#
# using namespace std;
#
# int majority(vector<int> &x)
# {
#     // should return i where either i==-1 if there is no majority
#     // element, or if 0<=i<x.size() where x[i] is the majority
#     // element.
# }
#
# #define WRONG { cout << "Nope!" << endl; return 0; }
#
# int main(void)
# {
#     vector<int> x1{1,2,3,4,3,2,2,2,2,2,2};
#     vector<int> x2{8,9,10};
#     int maj1 = majority(x1);
#     int maj2 = majority(x2);
#     //cout << maj1 << " " << maj2 << endl;
#     if(maj1==-1) WRONG;
#     if(maj1>=x1.size()) WRONG;
#     if(x1[maj1]!=2) WRONG;
#     if(maj2!=-1) WRONG;
#     cout << "You got it!" << endl;
#     return 0;
# }
# ```
