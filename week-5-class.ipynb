# %% [markdown]
# # Week 5 Class
#
# This week's question is from the 2013 Algorithms and Complexity exam, Q3. It's possible to easily find answers to this, but I'd recommend you don't do that. I won't be asking any group to present their answers to encourage you not to just look up the answers.
#
# ![image.png](attachment:image.png)
#
# You could also try writing code for parts (a) and (c), optionally.
